# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)

# %%
from fastai.text import *
from pathlib import *
from functools import partial
from tqdm import tqdm
import re
import string
import shutil
import hashlib

# %%
from fastai.text import *

# %%
# !mkdir tanglish_texts

# %%
base_dir = Path("/content")
flist = list((base_dir/'tanglish_texts').glob("*"))
print(flist)
# Out:
# [PosixPath('/content/tanglish_texts/tamil_texts.txt')]

# %%
custom_symbols = ["xxfld", "xxmaj", "xxup", "xxrep", "xxwrep"]
str_specialcases = ",".join(custom_symbols)
print(str_specialcases)
# Out:
# xxfld,xxmaj,xxup,xxrep,xxwrep

# %%
#spm.SentencePieceTrainer.Train(f'--input={flist} --model_prefix=taen_spm --vocab_size=8000 --input_sentence_size=22500000 --unk_id=0 --bos_id=1 --eos_id=2 --pad_id=3 --unk_piece={text.transform.UNK} --bos_piece={text.transform.BOS} --eos_piece={text.transform.EOS} --pad_piece={text.transform.PAD} --user_defined_symbols={str_specialcases}')

# %%
file_path = "/content/tanglish_texts/tamil_texts.txt"

# %%
from pathlib import Path

flist = Path("/content/tanglish_texts/tamil_texts.txt")

if not flist.exists():
    print(f"Error: File not found at {flist}")
else:
    print(f"File found: {flist}")
# Out:
# File found: /content/tanglish_texts/tamil_texts.txt

# %%
import sentencepiece as spm

# %%
special_tokens = {
    "UNK": "<unk>",
    "BOS": "<s>",
    "EOS": "</s>",
    "PAD": "<pad>"
}



spm.SentencePieceTrainer.Train(
    f"--input={file_path} --model_prefix=taen_spm --vocab_size=170262 "
    f"--input_sentence_size=22500000 --unk_id=0 --bos_id=1 --eos_id=2 --pad_id=3 "
    f"--unk_piece={special_tokens['UNK']} --bos_piece={special_tokens['BOS']} "
    f"--eos_piece={special_tokens['EOS']} --pad_piece={special_tokens['PAD']} "
    f"--user_defined_symbols={str_specialcases}"
)

# %%
vs = 170262

# %%
sp = spm.SentencePieceProcessor()

# %%
sp.Load("taen_spm.model")
# Out:
# True

# %%
sp.EncodeAsPieces('how are you'.lower())
# Out:
# ['▁how', '▁are', '▁you']

# %%
sp.EncodeAsPieces('I am not satisfied with you'.lower())
# Out:
# ['▁i', '▁am', '▁not', '▁satisfie', 'd', '▁with', '▁you']

# %%
itos = [sp.IdToPiece(int(i)) for i in range(vs)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '<pad>',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  '_',
#  '▁Not',
#  'ffensive',
#  'o',
#  'a',
#  '▁',
#  'e',
#  '.',
#  's',
#  '...',
#  '▁TA',
#  '▁O',
#  '..',
#  'Insult',
#  'i',
#  'TW',
#  ',',
#  'argeted',
#  'u',
#  'm',
#  '▁OFF',
#  'la',
#  '▁la',
#  '▁da',
#  '▁NOT',
#  '▁like',
#  '....',
#  'USER',
#  'ensive',
#  'T',
#  '▁@',
#  'n',
#  '▁#',
#  '▁ah',
#  'ed',
#  'y',
#  'Group',
#  '▁a',
#  'fensive',
#  'um',
#  '▁nu',
#  '▁படம்',
#  '▁mass',
#  'k',
#  '▁movie',
#  '▁ku',
#  '▁level',
#  '▁oru',
#  '▁trailer',
#  'rgeted',
#  '▁padam',
#  'na',
#  '்',
#  '-',
#  'nu',
#  'r',
#  'ga',
#  '▁வாழ்த்துக்கள்',
#  'off',
#  'h',
#  '▁fans',
#  'an',
#  '▁thala',
#  'ku',
#  '▁I',
#  '▁Off',
#  'd',
#  '▁Thala',
#  '2',
#  '▁not',
#  'Unt',
#  '▁na',
#  'ing',
#  '▁sir',
#  'ya',
#  't',
#  '▁than',
#  '1',
#  '▁vera',
#  'TAG',
#  '▁va',
#  '▁punda',
#  'Tamil',
#  'of',
#  'da',
#  '▁சார்பாக',
#  'am',
#  '▁வெற்றி',
#  'l',
#  '▁iruku',
#  '4',
#  '.....',
#  'thu',
#  '8',
#  'en',
#  '▁pa',
#  '3',
#  '▁illa',
#  'I',
#  '▁Of',
#  '6',
#  '▁Vera',
#  'Target',
#  "'",
#  '▁super',
#  '▁u',
#  'tha',
#  '▁23',
#  'Unta',
#  '0',
#  '▁and',
#  'nga',
#  '▁இந்த',
#  'ive',
#  '5',
#  'ம்',
#  '▁tha',
#  '▁2',
#  '▁:',
#  '7',
#  '▁i',
#  'ndividual',
#  '▁waiting',
#  '▁anna',
#  'ka',
#  '▁...',
#  'sive',
#  '?',
#  '▁in',
#  '▁s',
#  '▁enna',
#  'nsive',
#  'offe',
#  'offen',
#  '▁1',
#  '▁.',
#  '▁ya',
#  '▁is',
#  '9',
#  '▁பெற',
#  '▁nalla',
#  '▁,',
#  '▁to',
#  '▁Tam',
#  'HL',
#  '▁p',
#  'aa',
#  'In',
#  'ha',
#  '▁for',
#  'dividual',
#  'offens',
#  '▁fan',
#  '▁k',
#  '▁Anna',
#  'ra',
#  '▁RT',
#  'ma',
#  '▁irukku',
#  'al',
#  '▁A',
#  '▁semma',
#  '▁likes',
#  '▁hit',
#  'ும்',
#  '▁nee',
#  '▁intha',
#  '▁panna',
#  '▁Vijay',
#  '▁love',
#  '▁the',
#  'Ta',
#  '▁..',
#  '▁v',
#  '▁e',
#  'lam',
#  'ai',
#  '▁m',
#  'ar',
#  '▁pola',
#  '▁unaku',
#  '▁po',
#  '▁ஒரு',
#  '▁Surya',
#  '▁romba',
#  'es',
#  '▁ma',
#  '▁t',
#  '▁Trailer',
#  'le',
#  '!',
#  'g',
#  '▁ka',
#  '▁you',
#  'kku',
#  '▁vijay',
#  '▁தான்',
#  '▁en',
#  'iya',
#  'ru',
#  'in',
#  '▁thaan',
#  '▁am',
#  '▁bro',
#  '▁ne',
#  'er',
#  '▁views',
#  'v',
#  '▁but',
#  '▁panni',
#  '▁un',
#  '▁teaser',
#  '▁sema',
#  'than',
#  '▁poi',
#  '▁சாதி',
#  '▁mattum',
#  'p',
#  '▁unga',
#  'ு',
#  '▁so',
#  'ை',
#  '......',
#  'dhu',
#  ')',
#  'inga',
#  '▁3',
#  'du',
#  'ey',
#  'f',
#  '▁surya',
#  'il',
#  '▁n',
#  'ta',
#  've',
#  '▁dhan',
#  '▁S',
#  'ye',
#  '▁Enna',
#  '"',
#  '▁marana',
#  '▁Padam',
#  '▁it',
#  '▁podunga',
#  '▁....',
#  '▁vara',
#  'tu',
#  '▁bgm',
#  'va',
#  '▁b',
#  '▁Super',
#  '▁ellam',
#  '▁ithu',
#  'di',
#  '▁d',
#  'ne',
#  'ana',
#  '▁release',
#  '▁mela',
#  '▁enga',
#  '▁film',
#  'c',
#  '▁-',
#  '▁here',
#  'b',
#  '▁10',
#  '▁N',
#  '▁indha',
#  'ின்',
#  '▁dialogue',
#  '▁Mass',
#  '▁(',
#  '▁pakka',
#  '▁of',
#  '▁loosu',
#  'ே',
#  'Other',
#  'pa',
#  '▁maari',
#  '▁aa',
#  '▁from',
#  '▁thevidiya',
#  '▁me',
#  '▁ha',
#  '▁music',
#  '▁mari',
#  'om',
#  '▁iruka',
#  'w',
#  '▁ஜாதி',
#  '▁ena',
#  '▁kuda',
#  '▁NGK',
#  '▁mathiri',
#  '▁irukum',
#  'anga',
#  'yum',
#  '▁P',
#  '▁இது',
#  '▁r',
#  'M',
#  '▁Intha',
#  '▁neraya',
#  '▁koothi',
#  '▁star',
#  'te',
#  '▁se',
#  '▁4',
#  '▁Dei',
#  '▁neenga',
#  '▁o',
#  '▁yen',
#  'ah',
#  '▁ajith',
#  'ala',
#  '▁all',
#  '▁thalaiva',
#  '▁ye',
#  '▁Oru',
#  '▁pannunga',
#  'uku',
#  '▁"',
#  '▁Rajini',
#  'th',
#  'z',
#  'on',
#  '▁&',
#  '▁my',
#  '▁oda',
#  '▁h',
#  '▁ve',
#  '▁tamil',
#  '▁th',
#  'aga',
#  '▁M',
#  '▁5',
#  'gal',
#  '▁antha',
#  '▁c',
#  'kum',
#  'aaa',
#  '▁sa',
#  '▁Semma',
#  '▁paarunga',
#  '▁Suriya',
#  '▁y',
#  '▁l',
#  'ly',
#  '▁eppadi',
#  '▁avan',
#  '▁no',
#  '▁time',
#  '▁Like',
#  'ன்',
#  'K',
#  '▁Ajith',
#  'unga',
#  'athu',
#  '▁lam',
#  '▁வாழ்த்துகள்',
#  'ா',
#  'oda',
#  'chi',
#  '▁vanthu',
#  '▁be',
#  '▁scene',
#  '▁dislike',
#  'கள்',
#  'aru',
#  'ukku',
#  '▁rajini',
#  '▁g',
#  '▁thalaivar',
#  '▁kooda',
#  '▁pathi',
#  'st',
#  'dha',
#  '▁Marana',
#  '▁video',
#  '▁wait',
#  '▁K',
#  '▁U',
#  ':',
#  'chu',
#  '▁on',
#  '▁திரௌபதி',
#  'j',
#  '▁காதல்',
#  '▁comment',
#  '▁vaa',
#  '▁athu',
#  'ri',
#  '▁best',
#  '▁"@',
#  '▁poda',
#  'க்கு',
#  '▁Dai',
#  'ni',
#  '▁ke',
#  '▁suriya',
#  '▁ko',
#  'hu',
#  '▁pan',
#  '▁T',
#  'ama',
#  '▁vida',
#  '▁நாடக',
#  '▁iruntha',
#  'num',
#  'q',
#  '▁this',
#  'hi',
#  '▁sonna',
#  '▁ila',
#  '▁varum',
#  'து',
#  're',
#  'ng',
#  'ge',
#  '▁Thalaivar',
#  '▁idhu',
#  '▁dha',
#  '▁Ku',
#  '▁hai',
#  '▁என்று',
#  'ke',
#  'ee',
#  '▁100',
#  '▁per',
#  'li',
#  '▁pundai',
#  '▁veetla',
#  '▁Na',
#  '▁BGM',
#  '▁amma',
#  '▁innum',
#  '▁thalapathy',
#  '▁Tamil',
#  '▁இருக்கு',
#  'ல',
#  '▁ni',
#  'gala',
#  'ti',
#  '▁ipdi',
#  '▁வேண்டும்',
#  'க',
#  'ers',
#  'lla',
#  '▁potta',
#  '▁f',
#  '▁vetri',
#  '▁நான்',
#  'thi',
#  '▁pera',
#  '▁Indha',
#  '▁?',
#  '▁one',
#  'ில்',
#  '▁w',
#  '▁aana',
#  '▁Thalapathy',
#  '▁B',
#  '▁Nee',
#  '!!',
#  '▁hero',
#  '▁Da',
#  'x',
#  '▁solla',
#  'னு',
#  '▁atha',
#  '▁support',
#  '10',
#  '▁Romba',
#  '▁pottu',
#  '▁ra',
#  '▁V',
#  '▁E',
#  '▁solli',
#  'the',
#  'atha',
#  '▁naa',
#  '▁ki',
#  '▁என்ன',
#  '▁an',
#  '▁namma',
#  '▁Sema',
#  '▁வன்னியர்',
#  '▁j',
#  '▁irukkum',
#  '▁Movie',
#  '▁song',
#  '▁Ada',
#  '▁back',
#  '▁periya',
#  '▁style',
#  '▁epdi',
#  'ki',
#  '▁pathu',
#  '▁konjam',
#  '▁அண்ணா',
#  '.......',
#  '▁.....',
#  '▁man',
#  '▁nan',
#  'ada',
#  '▁ella',
#  '▁Sir',
#  'ல்',
#  '▁irukka',
#  '▁um',
#  'is',
#  '▁Nalla',
#  '▁are',
#  'rs',
#  '▁C',
#  '▁7',
#  '▁look',
#  '▁Waiting',
#  'me',
#  '▁வெற்றியடைய',
#  '▁pana',
#  '▁மட்டும்',
#  'se',
#  '▁Thalaiva',
#  'van',
#  '▁pe',
#  '▁இருக்கும்',
#  '▁மக்கள்',
#  '▁6',
#  'as',
#  'de',
#  '▁திரைப்படம்',
#  '▁acting',
#  '▁vantha',
#  '▁ta',
#  'si',
#  'ns',
#  '▁potu',
#  '▁padatha',
#  '▁En',
#  '▁THALA',
#  'ுக்கு',
#  'kal',
#  '▁படத்தை',
#  '▁மோகன்',
#  'தான்',
#  '▁Fans',
#  'ur',
#  '▁enaku',
#  '▁podu',
#  '▁inga',
#  '▁மாதிரி',
#  '▁Ithu',
#  '▁But',
#  '▁pannu',
#  '▁தமிழ்',
#  'lo',
#  '▁re',
#  'nnu',
#  '▁he',
#  '▁manasu',
#  '▁naan',
#  '▁pani',
#  '▁அடைய',
#  '▁Love',
#  '▁அனைத்து',
#  '▁first',
#  'geted',
#  '▁le',
#  '▁மாவட்டம்',
#  '▁di',
#  'Tar',
#  '▁kitta',
#  'ாக',
#  '▁pothu',
#  '▁சமுதாயம்',
#  '▁cinema',
#  '▁ad',
#  '▁eh',
#  '▁Unaku',
#  '▁yaru',
#  '▁veri',
#  '▁Hit',
#  '▁patha',
#  'kka',
#  '▁Ena',
#  '▁தல',
#  '▁ba',
#  '!!!',
#  '▁andha',
#  '▁naal',
#  '▁96',
#  'ttu',
#  '▁Unga',
#  '▁ok',
#  '▁matum',
#  '▁அருமை',
#  '▁D',
#  'ji',
#  '▁panra',
#  '▁as',
#  '▁vi',
#  '▁20',
#  '▁eduthu',
#  '▁masss',
#  'lu',
#  '▁kola',
#  '▁mokka',
#  'ay',
#  '▁என்',
#  '▁Yuvan',
#  'uthu',
#  'lum',
#  'ara',
#  '▁su',
#  '▁+',
#  '▁ana',
#  'ram',
#  '▁Teaser',
#  'el',
#  '??',
#  'or',
#  '▁or',
#  '▁ippo',
#  '▁story',
#  '▁அந்த',
#  '▁petta',
#  '▁sollu',
#  '▁entha',
#  '▁irunthu',
#  '▁nala',
#  '▁big',
#  '▁eruku',
#  '▁8',
#  '▁R',
#  '▁last',
#  '▁டா',
#  '▁iru',
#  '▁ava',
#  '▁uh',
#  '▁viswasam',
#  '▁pora',
#  '▁par',
#  '▁jathi',
#  'aaaa',
#  '▁by',
#  '▁just',
#  '▁!',
#  'adhu',
#  '▁போல',
#  '▁இல்லை',
#  '▁use',
#  'aya',
#  '▁unna',
#  '▁summa',
#  '▁adi',
#  '▁de',
#  'aaaaaaaaaaaaaaaa',
#  '▁Hindi',
#  'thaan',
#  'vanga',
#  '▁sol',
#  '▁good',
#  '▁vachi',
#  'anum',
#  '▁mudiyathu',
#  '▁jaathi',
#  'thala',
#  '▁we',
#  '▁All',
#  '▁Bro',
#  '▁trending',
#  '▁at',
#  '▁short',
#  'iye',
#  '▁எங்க',
#  '▁Naan',
#  '▁Petta',
#  'ch',
#  '▁name',
#  '▁varuthu',
#  'nd',
#  'ringa',
#  '▁ipo',
#  '▁paru',
#  '▁very',
#  'cha',
#  '▁up',
#  '▁kids',
#  '(',
#  'oo',
#  '▁paaka',
#  '▁copy',
#  'iyum',
#  '▁9',
#  '▁adhu',
#  '▁Enga',
#  '▁நல்ல',
#  '▁dei',
#  '▁tweet',
#  '▁million',
#  '▁full',
#  'S',
#  'man',
#  '▁id',
#  '▁itha',
#  '▁மாபெரும்',
#  'illa',
#  '???',
#  '▁vandhu',
#  '▁ur',
#  'மற்றும்',
#  'to',
#  'dhan',
#  'டா',
#  'he',
#  '▁Ella',
#  'ila',
#  '▁பார்க்க',
#  '▁dhaan',
#  'anu',
#  '▁Un',
#  '▁vela',
#  '▁irundha',
#  'oooooooooooooooo',
#  '▁looks',
#  '▁sari',
#  '▁makkal',
#  '▁daa',
#  'vum',
#  '▁F',
#  '▁avanga',
#  '▁ravi',
#  'nna',
#  '▁theri',
#  '▁asinga',
#  '▁caste',
#  '▁paaru',
#  '▁over',
#  '▁G',
#  'ன',
#  'at',
#  '▁Namma',
#  '▁vj',
#  '▁pann',
#  '▁Va',
#  '▁Bigil',
#  '▁mavane',
#  '▁அது',
#  '▁pad',
#  'ran',
#  '▁comedy',
#  'it',
#  'Indi',
#  '▁ivlo',
#  '▁illama',
#  'pu',
#  '▁day',
#  '▁feel',
#  'A',
#  'யும்',
#  '▁evlo',
#  '▁Avan',
#  'Ind',
#  '▁எல்லாம்',
#  '▁ungala',
#  '▁after',
#  '▁Last',
#  '▁onnu',
#  'vi',
#  '▁mo',
#  '▁ch',
#  'vidual',
#  '▁குல',
#  '▁tag',
#  '▁see',
#  '▁padathula',
#  '▁Dislike',
#  '▁director',
#  '▁varala',
#  '▁vachu',
#  '▁peru',
#  'alum',
#  '▁Mari',
#  '▁mu',
#  'ividual',
#  '▁will',
#  'ry',
#  'ngala',
#  '▁ir',
#  '▁STR',
#  '▁police',
#  '▁நீ',
#  'uu',
#  'ppa',
#  '▁Bgm',
#  '▁next',
#  'kala',
#  '▁kulla',
#  '▁kat',
#  '▁king',
#  '▁sethupathi',
#  '▁நன்றி',
#  '▁90',
#  '........',
#  '▁solra',
#  '▁ketta',
#  'ர்',
#  '▁venum',
#  '▁part',
#  'ce',
#  '▁apdi',
#  '▁kena',
#  'un',
#  '▁அ',
#  '▁porom',
#  'alam',
#  '▁mar',
#  'adi',
#  'rathu',
#  '▁பெண்',
#  'ir',
#  'nda',
#  'ii',
#  '▁yuvan',
#  'and',
#  '▁Vara',
#  '▁!!',
#  '▁semaya',
#  '▁500',
#  '▁remake',
#  'nam',
#  '▁இல்ல',
#  '▁leval',
#  '▁sollunga',
#  '▁No',
#  '▁yaaru',
#  '▁al',
#  '▁always',
#  'ங்க',
#  '▁ethu',
#  '▁ippadi',
#  '▁hi',
#  '▁var',
#  '▁paka',
#  '▁Vikram',
#  '▁Idhu',
#  '▁pat',
#  '▁irruku',
#  '▁சொல்லி',
#  'ad',
#  '▁flop',
#  'mmmmmmmmmmmmmmmm',
#  '▁appo',
#  'et',
#  '▁ellarum',
#  '▁wow',
#  '▁dai',
#  'uuu',
#  'll',
#  'enga',
#  '▁ponga',
#  '▁pu',
#  'sa',
#  '▁that',
#  '▁Dhanush',
#  '▁kerala',
#  '▁comments',
#  '▁str',
#  '▁pona',
#  'im',
#  '▁ja',
#  'ithu',
#  '▁Ne',
#  '▁எந்த',
#  '+',
#  '▁adha',
#  '▁avar',
#  'ts',
#  'gu',
#  '▁thana',
#  '100',
#  '▁appa',
#  'kkum',
#  'thula',
#  '▁oombu',
#  'ellam',
#  '▁கொங்கு',
#  '▁ulla',
#  '▁real',
#  '▁voice',
#  'ea',
#  '▁kar',
#  '▁maathiri',
#  'ae',
#  '▁Antha',
#  '▁pandra',
#  '▁kandipa',
#  '▁lo',
#  'iii',
#  '▁go',
#  '▁Tha',
#  '▁Inga',
#  '▁kita',
#  '▁with',
#  '▁work',
#  'ted',
#  '▁பல',
#  '▁nanga',
#  '▁do',
#  '▁only',
#  '▁Punda',
#  '▁si',
#  '▁madhiri',
#  'ies',
#  '▁Pa',
#  '▁days',
#  'ula',
#  '▁vanga',
#  '▁pesa',
#  '▁mudiyala',
#  'sh',
#  '▁vere',
#  '▁L',
#  'ranga',
#  '▁pannitu',
#  '▁சார்பில்',
#  '▁awesome',
#  '▁paatha',
#  '▁rendu',
#  '▁mat',
#  '▁varanum',
#  '▁blockbuster',
#  '▁30',
#  '▁paathu',
#  '▁12',
#  '▁theriyum',
#  '▁கவுண்டர்',
#  'ால்',
#  '▁ho',
#  '▁pongal',
#  '▁=',
#  '▁நீங்க',
#  '▁Ravi',
#  '▁irukan',
#  '▁poola',
#  'us',
#  'ss',
#  '▁gethu',
#  '▁life',
#  '▁arasiyal',
#  '▁pathutu',
#  'hal',
#  '▁Ennada',
#  '▁vittu',
#  '▁சமூகம்',
#  '▁Telugu',
#  'P',
#  '▁pota',
#  '▁ga',
#  'yo',
#  '▁11',
#  '▁LA',
#  '▁paya',
#  '▁kaga',
#  '▁Thevidiya',
#  '▁எல்லா',
#  '15',
#  '▁Shankar',
#  '▁thu',
#  '▁great',
#  'nt',
#  'ி',
#  '▁paiyan',
#  '▁ivan',
#  '▁வரும்',
#  '▁raja',
#  '▁kan',
#  '▁Loosu',
#  '▁vikram',
#  '▁vandha',
#  'ோ',
#  'ting',
#  'po',
#  '▁Th',
#  '▁எங்கள்',
#  '▁paa',
#  '▁apo',
#  '▁yenna',
#  'ba',
#  '▁pasangala',
#  ...]

# %%
[tok for tok in itos if len(tok) < 2]
# Out:
# ['_',
#  'o',
#  'a',
#  '▁',
#  'e',
#  '.',
#  's',
#  'i',
#  ',',
#  'u',
#  'm',
#  'T',
#  'n',
#  'y',
#  'k',
#  '்',
#  '-',
#  'r',
#  'h',
#  'd',
#  '2',
#  't',
#  '1',
#  'l',
#  '4',
#  '8',
#  '3',
#  'I',
#  '6',
#  "'",
#  '0',
#  '5',
#  '7',
#  '?',
#  '9',
#  '!',
#  'g',
#  'v',
#  'p',
#  'ு',
#  'ை',
#  ')',
#  'f',
#  '"',
#  'c',
#  'b',
#  'ே',
#  'w',
#  'M',
#  'z',
#  'K',
#  'ா',
#  ':',
#  'j',
#  'q',
#  'ல',
#  'க',
#  'x',
#  '(',
#  'S',
#  'ன',
#  'A',
#  '+',
#  'P',
#  'ி',
#  'ோ',
#  'D',
#  'N',
#  '#',
#  'R',
#  '/',
#  'à',
#  'ய',
#  ';',
#  'Y',
#  'G',
#  'E',
#  'U',
#  '🤣',
#  '&',
#  '\\',
#  'α',
#  '🤔',
#  '’',
#  'L',
#  '=',
#  'O',
#  'é',
#  '*',
#  'H',
#  '[',
#  'ற',
#  '🤩',
#  'V',
#  'B',
#  'ர',
#  '%',
#  '®',
#  '്',
#  'வ',
#  '్',
#  '@',
#  'ा',
#  ']',
#  'ள',
#  'C',
#  '🤗',
#  'â',
#  '್',
#  'ಿ',
#  'í',
#  'W',
#  'े',
#  'є',
#  'ᗩ',
#  'и',
#  '\u200d',
#  'J',
#  'ம',
#  '”',
#  'ا',
#  'ാ',
#  'ப',
#  'ீ',
#  'X',
#  'த',
#  'ല',
#  'ه',
#  'ó',
#  'F',
#  '🤘',
#  'ಾ',
#  'ി',
#  'á',
#  'ా',
#  '¦',
#  'र',
#  'ñ',
#  'ι',
#  'ي',
#  'ட',
#  'е',
#  'ā',
#  'క',
#  'ు',
#  'ூ',
#  '௫',
#  'ஐ',
#  '्',
#  'ã',
#  'ದ',
#  'о',
#  'ب',
#  'ع',
#  'ú',
#  'т',
#  'Z',
#  'د',
#  'ெ',
#  'م',
#  '\x8d',
#  'ę',
#  '🥰',
#  'ే',
#  'ಡ',
#  'ك',
#  'м',
#  'न',
#  '>',
#  'ழ',
#  '$',
#  'ర',
#  'ச',
#  'డ',
#  'ల',
#  'स',
#  'ß',
#  '~',
#  '£',
#  'و',
#  '🤝',
#  'ı',
#  'ق',
#  'ರ',
#  'ం',
#  'ą',
#  '🤨',
#  'వ',
#  '🤭',
#  'ಮ',
#  'ண',
#  'è',
#  'ر',
#  'ి',
#  '🤪',
#  'ತ',
#  '🤙',
#  'న',
#  'क',
#  'ು',
#  '🧐',
#  'ø',
#  'அ',
#  '🤫',
#  '🤓',
#  'ل',
#  'ç',
#  'మ',
#  'ś',
#  '🦁',
#  'ł',
#  'ಕ',
#  'ொ',
#  'உ',
#  '🤟',
#  'ş',
#  'ت',
#  'ن',
#  'س',
#  'எ',
#  'ந',
#  'இ',
#  'ஜ',
#  'ö',
#  'н',
#  '⃣',
#  'ஆ',
#  'ನ',
#  'ف',
#  '🥳',
#  'ѕ',
#  'ஊ',
#  'ஏ',
#  'ங',
#  'ಲ',
#  'ஓ',
#  'ஸ',
#  'ê',
#  'స',
#  'ż',
#  'ద',
#  'ട',
#  '|',
#  '‚',
#  'ஒ',
#  'త',
#  '🤬',
#  'ஷ',
#  'ə',
#  'ஈ',
#  '🤮',
#  'ஞ',
#  'ക',
#  '¤',
#  '🤦',
#  'ش',
#  'ஹ',
#  '🥺',
#  '¡',
#  '\x81',
#  'Q',
#  '“',
#  'š',
#  '̄',
#  '‘',
#  'ஃ',
#  '\xad',
#  'ğ',
#  'ü',
#  '<',
#  'ௌ']

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai, torch
fastai.__version__ , torch.__version__
# Out:
# ('2.7.18', '2.5.1+cu124')

# %%
# !pwd
# Out:
# /content

# %%
from fastai.text import *
from typing import List

# %%
# Define preprocessing functions
def lower_case_everything(t: str) -> str:
    return t.lower()

def replace_all_caps(tokens: List[str]) -> List[str]:
    return [f'xxup {t.lower()}' if t.isupper() else t for t in tokens]

def deal_caps(tokens: List[str]) -> List[str]:
    return [f'xxmaj {t}' if t.istitle() else t for t in tokens]

def handle_all_caps(t: str) -> str:
    tokens = t.split()
    tokens = replace_all_caps(tokens)
    return ' '.join(tokens)

def handle_upper_case_first_letter(t: str) -> str:
    tokens = t.split()
    tokens = deal_caps(tokens)
    return ' '.join(tokens)

# %%
sp = spm.SentencePieceProcessor()
sp.Load(str("/content/taen_spm.model"))
itos = [sp.IdToPiece(int(i)) for i in range(vs)]

# %%
len(itos)
# Out:
# 170262

# %%
itos[:20]
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '<pad>',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  '_',
#  '▁Not',
#  'ffensive',
#  'o',
#  'a',
#  '▁',
#  'e',
#  '.',
#  's',
#  '...',
#  '▁TA']

# %%
from fastai.text.all import Numericalize

# %%
from fastai.text.all import BaseTokenizer

# %%
class CodeMixedTamilTokenizer(BaseTokenizer):
    def __init__(self, lang:str):
        self.lang = lang
        self.sp = spm.SentencePieceProcessor()
        self.sp.Load(str("/content/taen_spm.model"))

    def __call__(self, items):  # Ensure FastAI recognizes it as a callable tokenizer
        return [self.sp.EncodeAsPieces(t) for t in items]

    def tokenizer(self, items):
        return [self.sp.EncodeAsPieces(t) for t in items]

# %%
sp = spm.SentencePieceProcessor()
sp.Load(str("/content/taen_spm.model"))
itos = [sp.IdToPiece(int(i)) for i in range(vs)]

# %%
taen_vocab = Numericalize(vocab=itos)

# %%
custom_pre_rules = [lower_case_everything, handle_all_caps, handle_upper_case_first_letter]

# %%
from fastai.text.all import Tokenizer

# %%
tokenizer = Tokenizer( CodeMixedTamilTokenizer(lang="taen"),rules=custom_pre_rules)

# %%
tokenizer
# Out:
# Tokenizer:
# encodes: (Path,object) -> encodes
# (str,object) -> encodes
# decodes: (object,object) -> decodes

# %%
token1 = tokenizer('dei thampi enna intha pakkam')
token2 = tokenizer('bro saptingala')
print(token1)
print(token2)
# Out:
# ['▁dei', '▁thampi', '▁enna', '▁intha', '▁pakkam']
# ['▁bro', '▁saptingala']
